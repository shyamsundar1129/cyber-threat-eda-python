# %%
# Import all modules 
from data_loader import DataLoader
from data_processor import DataProcessor  
from data_analyzer import DataAnalyzer  
from data_visualizer import DataVisualizer  
from dashboard_creator import CyberSecurityDashboard  
from threat_analyzer import ThreatAnalyzer  
from financial_impact import FinancialImpact  
from security_metrics import SecurityMetrics

# %%
# Initialize data processor and load data  
filepath = "GCST - Python.csv"  
processor = DataProcessor(filepath)  
df = processor.load_data()  
df = processor.clean_data()
# Out:
# Data loaded successfully.
# Data cleaned successfully.

# %%
# Run analyses  
analyzer = DataAnalyzer(df)  
attack_trends = analyzer.basic_statistics()  
country_stats = analyzer.analyze_by_year()
# Out:
# Basic statistics calculated:
#               Year  FinancialLoss  NumberofAffectedUsers  \
# count  3000.000000    3000.000000            3000.000000
# mean   2019.570333      50.492970          504684.136333
# std       2.857932      28.791415          289944.084972
# min    2015.000000       0.500000             424.000000
# 25%    2017.000000      25.757500          255805.250000
# 50%    2020.000000      50.795000          504513.000000
# 75%    2022.000000      75.630000          758088.500000
# max    2024.000000      99.990000          999635.000000
#
#        IncidentResolutionTime
# count             3000.000000
# mean                36.476000
# std                 20.570768
# min                  1.000000
# 25%                 19.000000
# 50%                 37.000000
# 75%                 55.000000
# max                 72.000000
# Yearly analysis completed:
#       FinancialLoss  NumberofAffectedUsers
# Year
# 2015       14510.21              141293170
# ...

# %%
# Create visualizations  
visualizer = DataVisualizer(df)  
visualizer.plot_financial_loss_by_year()
# Out:
# Financial loss pie chart displayed successfully.

# %%
# Financial impact analysis  
financial = FinancialImpact(df)  
financial.impact_by_industry()
# Out:
# Financial impact computed by target industry:
#        TargetIndustry  FinancialLoss
# 0             Banking       22772.39
# 1           Education       20071.43
# 2          Government       21205.33
# 3          Healthcare       21041.29
# 4                  IT       24809.83
# 5              Retail       21119.55
# 6  Telecommunications       20459.09
# Impact by industry plot displayed successfully.

# %%
# Security metrics  
metrics = SecurityMetrics(df)  
resolution_stats = metrics.resolution_time_stats()  
metrics.vulnerability_analysis()
# Out:
# Resolution time metrics calculated:
# count    3000.000000
# mean       36.476000
# std        20.570768
# min         1.000000
# 25%        19.000000
# 50%        37.000000
# 75%        55.000000
# max        72.000000
# Name: IncidentResolutionTime, dtype: float64

# %%
# Create dashboard  
dashboard = CyberSecurityDashboard("GCST - Python.csv")  
dashboard.run()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Create dashboard
#       2 dashboard = CyberSecurityDashboard("GCST - Python.csv")
# ----> 3 dashboard.run()
#
# File ~\Downloads\Python files\dashboard_creator.py:143, in CyberSecurityDashboard.run(self)
#     142 def run(self):
# --> 143     self.app.run(debug=True)
#
# File ~\anaconda3\Lib\site-packages\dash\dash.py:2257, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_disable_version_check, dev_tools_prune_errors, **flask_run_options)
#    2254             extra_files.append(path)
# ...
